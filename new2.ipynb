# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
from IPython.display import display
from PIL import Image
import numpy as np
from keras.preprocessing import image
import tensorflow as tf

# %%
model = tf.keras.models.load_model("m.h5")

# %%
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
test_image = tf.keras.utils.load_img('G1.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('G2.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('G112.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('F1.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('fff.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('SIGN.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
print(result)
# Out:
# 1/1 [==============================] - 0s 113ms/step
# Genuine
# [[1.]]

# %%
test_image = tf.keras.utils.load_img('o.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('oo.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('i.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('ii.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine

# %%
test_image = tf.keras.utils.load_img('S135.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
print(result)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine
# [[1.]]

# %%
test_image = tf.keras.utils.load_img('t.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
print(result)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Genuine
# [[1.]]

# %%
test_image = tf.keras.utils.load_img('t.png', target_size = (150, 220))
plt.imshow(test_image)
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
if result[0][0] >= 0.5:
    prediction = 'Genuine'
else:
    prediction = 'forged'
print(prediction)
print(result)
# Out:
# 1/1 [==============================] - 0s 0s/step
# Genuine
# [[1.]]
